# %%
import requests
from bs4 import BeautifulSoup as soup
url = 'https://www.philips.co.in/'
link = requests.get(url).text
page = soup(link, 'html.parser')

# %%
category = set()
for i in page.find_all('span', class_ = 'p-body-copy-01 p-heading-light p-n02v3__m2text'):
    category.add(i.string.strip())
category = list(category)
print(category)
# Out:
# ['Mother & child care', 'Lighting', 'Health', 'Automotive', 'Parts & Accessories', 'Promotions', 'Personal care', 'Household products', 'Sound & vision']

# %%
nav_bar = page.find('ul', class_ = 'p-n02v3__m2 p-n02v3__micon')
data ={}
a = 'string'
li = nav_bar.find('div',class_ ='p-heading-02 p-heading-light')
for li in nav_bar.findAll('div',class_ ='p-heading-02 p-heading-light'):
    li = li.string
    if li in category:
        a = li
        data[a] = []
    else:
        data[a] += [li]
for key,val in data.items():
    print(key,':',val)
# Out:
# Sound & vision : ['TV and video', 'Audio', 'Communication', 'Accessories']
# Personal care : ['For Men', 'For Women', 'Oral Health Care']
# Mother & child care : ['Guidance & Support', 'For babies', 'For toddlers']
# Household products : ['Drinks', 'Prepare & Cook', 'Ironing & Cleaning', 'Air Care']
# Lighting : ['Philips Hue', 'Consumer lighting']
# Health : ['Hearing Solutions', 'Respiratory care', 'Sleep']
# Automotive : ['Car', 'Motorcycle', 'Accessories', 'Support']
# Parts & Accessories : ['Parts and accessories']
# Promotions : []

# %%
product_sub_category = []
for li in nav_bar.findAll('li'):
    li = li.findAll('span')[-1].string
    if li not in product_sub_category:
        product_sub_category.append(li)
print(product_sub_category,'\n')
# Out:
# ['Computer accessories', 'Media players', 'TV', 'Monitors', 'Wireless Speakers', 'Home Audio', 'Soundbars', 'Headphones', 'Data storage', 'Mobile & tablets', 'Audio & video', 'Batteries & chargers', 'Power solutions', 'Mobile accessories', 'Teeth Whitening', 'BODY groomers', 'OneBlade – Shape, trim and shave', 'FACE Shavers', 'Beard Trimmers and Grooming Kits', 'HAIR clippers', 'Haircare', 'Beauty Tips for Women', 'Satinelle epilator', 'Hair removal', 'Oral Healthcare Homepage', 'Electric Toothbrushes', 'Toothbrush heads', 'Philips Sonicare AirFloss', 'Toddler sippy cups', 'Healthcare professionals', 'Philips Avent homepage', 'Bottle warmers & sterilizers', 'Breast pumps & care', 'Baby bottles & nipples', 'Food makers & tableware', 'Pacifiers', 'Air purifier and Air humidifier', 'Kettles', 'Coffee', 'Food Preparation', 'Cooking', 'Garment steamers', 'Vacuum Cleaners', 'Ironing', 'Consumer lighting', 'Philips Hue', 'Sleep apnea Therapy', 'Hearing solutions', 'COPD Solutions', 'Where to buy', 'All car lights', 'Car lights', 'Halogen ', 'LED', 'All motorcycle lights', 'Motorcycle lights', 'Halogen', 'Car air quality', 'Car accessories', 'Automotive support', 'Automotive articles', 'Parts and accessories', 'Promotions']

# %%
sub_category = {}
# ul =html.find_all('ul', class_ = 'p-n02v3__m4 p-n02v3__m--col24')
for i in page.find_all('ul', class_ = 'p-n02v3__m4 p-n02v3__m--col24'):
    for li in i.find_all('li'):
        sub_category[li.find('span').string.strip()]={}
        a = li.find('a').get('href')
        try:
            new_link = requests.get(a).text
            sub_category_page = soup(new_link,'html.parser')            
            for x in sub_category_page.find_all('div', class_='p-pc05v2__card-info-section--main'):
                sku_url = x.find('a').get('href')
                sku_name = x.find('span',class_='p-heading-light').string.strip()
                product_code = x.find('p').string.strip()
                sub_category[li.find('span').string.strip()][sku_name]={}
                sub_category[li.find('span').string.strip()][sku_name]['Product code'] = product_code
                technical_link = requests.get(sku_url).text
                technical_page = soup(technical_link,'html.parser')
                header = []
                value = []
                for col1 in technical_page.find_all('dt'):
                    header.append(col1.string.strip())

                for col2 in technical_page.findAll('dd'):
                    if col2.find('span'):
                        value.append(col2.find('span').string.strip())
                    else:
                        value.append('')
                sub_category[li.find('span').string.strip()][sku_name]['Technical Specification'] = {}
                for i in range(len(header)):
                    sub_category[li.find('span').string.strip()][sku_name]['Technical Specification'][header[i]] = value[i]
        except:
            pass
sub_category
# Out:
# {'TV': {'4K Ultra Slim Smart LED TV': {'Product code': '50PUT6103S/94',
#    'Technical Specification': {'Display': '4K Ultra HD LED',
#     'Panel resolution': '3840x2160',
#     'Aspect ratio': '16:9',
#     'Picture enhancement': 'Micro Dimming',
#     'User Interaction': 'MultiRoom client',
#     'Program': 'Pause TV',
#     'SmartTV apps*': 'Open internet browser',
#     'Ease of Installation': 'Device connection wizard',
#     'Firmware upgradeable': 'Firmware auto upgrade wizard',
#     'Screen Format Adjustments': 'Advance - Shift',
#     'Philips TV Remote app*': 'Apps',
#     'Output power (RMS)': '20W',
#     'Sound Enhancement': 'Incredible Surround',
#     'Number of HDMI connections': '3',
#     'Number of USBs': '2',
#     'Number of component in (YPbPr)': '1',
#     'Number of AV connections': '1',
#     'Wireless connections': 'Wi-Fi 802.11n 2x2 integrated',
#     'Other connections': 'Audio L/R in',
#     'HDMI features': 'Audio Return Channel',
#     'EasyLink (HDMI-CEC)': 'Remote control pass-through',
#     'Video Playback Formats': 'Containers: AVI, MKV',
#     'Subtitles Formats Support': '.SMI',
#     'Music Playback Formats': 'AAC',
#     'Picture Playback Formats': 'JPEG',
#     'Video inputs on HDMI1': 'up to 4K UHD 3840x 2160 @30Hz',
#     'Computer inputs on HDMI1': 'up to 4K UHD 3840x 2160 @30Hz',
#     'Computer inputs on HDMI2/3': 'up to 4K UHD 3840x 2160 @60Hz',
#     'Video inputs on HDMI2/3': 'up to 4K UHD 3840x 2160 @60Hz',
#     'Digital TV': 'DVB-T/T2',
#     'MPEG Support': 'MPEG2',
#     'Video Playback': 'NTSC',
#     'Signal strength indication': 'Yes',
#     'HEVC support': 'Yes',
#     'Mains power': '110 - 240V 50/60Hz',
#     'Ambient temperature': '5 °C to 35 °C',
#     'Power Saving Features': 'Auto switch-off timer',
#     'Box width': '1240\n                                                        \n                                                            \xa0mm',
#     'Box height': '800\n                                                        \n                                                            \xa0mm',
#     'Box depth': '150\n                                                        \n                                                            \xa0mm',
#     'Set Width': '1127.64\n                                                        \n                                                            \xa0mm',
#     'Set Height': '664.9\n                                                        \n                                                            \xa0mm',
#     'Set Depth': '85.9\n                                                        \n                                                            \xa0mm',
#     'Set width (with stand)': '1127.64\n                                                        \n                                                            \xa0mm',
#     'Set height (with stand)': '717\n                                                        \n                                                            \xa0mm',
#     'Set depth (with stand)': '241.3\n                                                        \n                                                            \xa0mm',
#     'VESA wall mount compatible': '200 x 200 mm',
#     'Product weight': '11.59\n                                                        \n                                                            \xa0kg',
#     'Product weight (+stand)': '11.79\n                                                        \n                                                            \xa0kg',
#     'Weight incl. Packaging': '16.6\n                                                        \n                                                            \xa0kg',
#     'Included accessories': 'Remote Control'}},
#   'Ultra Slim Full HD LED Smart TV': {'Product code': '43PFT5813S/94',
#    'Technical Specification': {'Display': 'LED Full HD',
#     'Panel resolution': '1920x1080p',
#     'Aspect ratio': '4:3/16:9',
#     'Picture enhancement': 'Pixel Plus HD',
#     'Output power (RMS)': '20W',
#     'Sound Enhancement': 'Incredible Surround',
#     'Number of HDMI connections': '2',
#     'Number of USBs': '2',
#     'Number of component in (YPbPr)': '1',
#     'Number of CVBS': '1',
#     'Other connections': 'Audio L/R in',
#     'EasyLink (HDMI-CEC)': 'Remote control pass-through',
#     'Wireless connections': 'Built-in 1T1R Single band',
#     'Video Playback Formats': 'Containers: AVI, MKV',
#     'Subtitles Formats Support': '.SMI',
#     'Music Playback Formats': 'AAC',
#     'Picture Playback Formats': 'JPEG',
#     'Computer inputs': 'up to 1920x1080 @ 60Hz',
#     'Video inputs': 'up to 1920x1080p',
#     'HEVC support': 'Yes',
#     'MPEG Support': 'MPEG2',
#     'Video Playback': 'NTSC',
#     'Digital TV': 'DVB-T/T2',
#     'Mains power': '110 - 240 V 50/60Hz',
#     'Ambient temperature': '5 °C to 35 °C',
#     'Power Saving Features': 'Auto switch-off timer',
#     'Box width': '1070\n                                                        \n                                                            \xa0mm',
#     'Box height': '680\n                                                        \n                                                            \xa0mm',
#     'Box depth': '140\n                                                        \n                                                            \xa0mm',
#     'Set Width': '969.6\n                                                        \n                                                            \xa0mm',
#     'Set Height': '562.5\n                                                        \n                                                            \xa0mm',
#     'Set Depth': '80.5\n                                                        \n                                                            \xa0mm',
#     'Set width (with stand)': '969.6\n                                                        \n                                                            \xa0mm',
#     'Set height (with stand)': '624.2\n                                                        \n                                                            \xa0mm',
#     'Set depth (with stand)': '194.0\n                                                        \n                                                            \xa0mm',
#     'VESA wall mount compatible': '200 x 200 mm',
#     'Product weight': '7.2\n                                                        \n                                                            \xa0kg',
#     'Product weight (+stand)': '7.3\n                                                        \n                                                            \xa0kg',
#     'Weight incl. Packaging': '9.6\n                                                        \n                                                            \xa0kg',
#     'Included accessories': 'Remote Control',
#     'Ease of Installation': 'Device connection wizard',
#     'Ease of Use': 'One-stop smart menu button',
#     'Firmware upgradeable': 'Firmware auto upgrade wizard',
#     'Philips TV Remote app*': 'Apps',
#     'Program': 'Pause TV',
#     'Screen Format Adjustments': 'Basic - Fill Screen',
#     'User Interaction': 'SimplyShare',
#     'SmartTV apps*': 'Netflix'}},
#   'Ultra Slim LED Smart TV': {'Product code': '32PHT5813S/94',
#    'Technical Specification': {'Display': 'LED HD Ready',
#     'Panel resolution': '1366 x 768p',
#     'Aspect ratio': '4:3/16:9',
#     'Picture enhancement': 'Pixel Plus HD',
#     'Output power (RMS)': '20W',
#     'Sound Enhancement': 'Incredible Surround',
#     'Number of HDMI connections': '2',
#     'Number of USBs': '2',
#     'Number of component in (YPbPr)': '1',
#     'Number of CVBS': '1',
#     'Other connections': 'Audio L/R in',
#     'EasyLink (HDMI-CEC)': 'Remote control pass-through',
#     'Wireless connections': 'Built-in 1T1R Single band',
#     'Video Playback Formats': 'Containers: AVI, MKV',
#     'Subtitles Formats Support': '.SMI',
#     'Music Playback Formats': 'AAC',
#     'Picture Playback Formats': 'JPEG',
#     'Computer inputs': 'up to 1366x768 @ 60Hz',
#     'Video inputs': 'up to 1366x768p',
#     'HEVC support': 'Yes',
#     'MPEG Support': 'MPEG2',
#     'Video Playback': 'NTSC',
#     'Digital TV': 'DVB-T/T2',
#     'Mains power': '110 - 240 V 50/60Hz',
#     'Ambient temperature': '5 °C to 35 °C',
#     'Power Saving Features': 'Auto switch-off timer',
#     'Box width': '798\n                                                        \n                                                            \xa0mm',
#     'Box height': '520\n                                                        \n                                                            \xa0mm',
#     'Box depth': '133\n                                                        \n                                                            \xa0mm',
#     'Set Width': '731.8\n                                                        \n                                                            \xa0mm',
#     'Set Height': '435.3\n                                                        \n                                                            \xa0mm',
#     'Set Depth': '81.0\n                                                        \n                                                            \xa0mm',
#     'Set width (with stand)': '731.8\n                                                        \n                                                            \xa0mm',
#     'Set height (with stand)': '494.1\n                                                        \n                                                            \xa0mm',
#     'Set depth (with stand)': '166.2\n                                                        \n                                                            \xa0mm',
#     'VESA wall mount compatible': 'X= 100mm',
#     'Product weight': '4.2\n                                                        \n                                                            \xa0kg',
#     'Product weight (+stand)': '4.3\n                                                        \n                                                            \xa0kg',
#     'Weight incl. Packaging': '6.1\n                                                        \n                                                            \xa0kg',
#     'Included accessories': 'Remote Control',
#     'Ease of Installation': 'Device connection wizard',
#     'Ease of Use': 'One-stop smart menu button',
#     'Firmware upgradeable': 'Firmware auto upgrade wizard',
#     'Philips TV Remote app*': 'Apps',
#     'Program': 'Pause TV',
#     'Screen Format Adjustments': 'Basic - Fill Screen',
#     'User Interaction': 'SimplyShare',
#     'SmartTV apps*': 'Netflix'}}},
#  'Monitors': {'LCD monitor': {'Product code': '221V8/94',
#    'Technical Specification': {'LCD panel type': 'VA LCD',
#     'Adaptive sync': 'Yes',
#     'Backlight type': 'W-LED system',
#     'Panel Size': '21.5 inch / 54.6 cm',
#     'Display Screen Coating': 'Anti-glare, 3H, Haze 25%',
#     'Effective viewing area': '476.6 (H) x 268.1 (V)',
#     'Aspect ratio': '16:9',
#     'Maximum resolution': '1920 x 1080 @ 75 Hz*',
#     'Pixel Density': '102 PPI',
#     'Response time (typical)': '4 ms (GtG)*',
#     'Brightness': '200\n                                                        \n                                                            \xa0cd/m²',
#     'Contrast ratio (typical)': '4000:1',
#     'SmartContrast': 'Mega Infinity DCR',
#     'Pixel pitch': '0.248 x 0.248 mm',
#     'Viewing angle': '178º (H) / 178º (V)',
#     'Display colors': '16.7 M',
#     'Picture enhancement': 'SmartImage',
#     'Scanning Frequency': '30 - 85 kHz (H) / 48 - 75 Hz (V)',
#     'sRGB': 'Yes',
#     'Flicker-free': 'Yes',
#     'LowBlue Mode': 'Yes',
#     'EasyRead': 'Yes',
#     'Signal Input': 'VGA (Analog )',
#     'Sync Input': 'Separate Sync',
#     'Audio (In/Out)': 'Audio out',
#     'User convenience': 'Power On/Off',
#     'OSD Languages': 'Brazil Portuguese',
#     'Other convenience': 'Kensington lock',
#     'Plug & Play Compatibility': 'DDC/CI',
#     'Tilt': '-5/20\n                                                        \n                                                            \xa0degree',
#     'On mode': '17.7 W (typ.)',
#     'Standby mode': '< 0.5 W (typ.)',
#     'Off mode': '< 0.3 W (typ.)',
#     'Power LED indicator': 'Operation - White',
#     'Power supply': 'Built-in',
#     'Product with stand (mm)': '492 x 376 x 220\n                                                        \n                                                            \xa0mm',
#     'Product without stand (mm)': '492 x 295 x 45\n                                                        \n                                                            \xa0mm',
#     'Packaging in mm (WxHxD)': '542 x 447 x 118\n                                                        \n                                                            \xa0mm',
#     'Product with stand (kg)': '2.60\n                                                        \n                                                            \xa0kg',
#     'Product without stand (kg)': '2.21\n                                                        \n                                                            \xa0kg',
#     'Product with packaging (kg)': '3.84\n                                                        \n                                                            \xa0kg',
#     'Temperature range (operation)': '0°C to 40°C\n                                                        \n                                                            \xa0°C',
#     'Temperature range (storage)': '-20°C to 60°C\n                                                        \n                                                            \xa0°C',
#     'Relative humidity': '20%-80\n                                                        \n                                                            \xa0%',
#     'Altitude': 'Operation: +12,000ft (3,658m), Non-operation: +40,000ft (12,192m)',
#     'MTBF': '50,000 (Excluded backlight)\n                                                        \n                                                            \xa0hour(s)',
#     'Environmental and energy': 'RoHS',
#     'Recyclable packaging material': '100\n                                                        \n                                                            \xa0%',
#     'Regulatory Approvals': 'CECP',
#     'Color': 'Black',
#     'Finish': 'Textured'}},
#   'Full HD LCD monitor': {'Product code': '223V7QHAW/94',
#    'Technical Specification': {'LCD panel type': 'IPS technology',
#     'Backlight type': 'W-LED system',
#     'Panel Size': '21.5 inch / 54.6 cm',
#     'Effective viewing area': '476.06 (H) x 267.79 (V)',
#     'Aspect ratio': '16:9',
#     'Maximum resolution': '1920 x 1080 @ 75 Hz*',
#     'Pixel Density': '102 PPI',
#     'Response time (typical)': '5 ms (GtG)*',
#     'Brightness': '250\n                                                        \n                                                            \xa0cd/m²',
#     'SmartContrast': '10,000,000:1',
#     'Contrast ratio (typical)': '1000:1',
#     'Pixel pitch': '0.248 x 0.248 mm',
#     'Viewing angle': '178º (H) / 178º (V)',
#     'Flicker-free': 'Yes',
#     'Display colors': '16.7 M',
#     'Scanning Frequency': '30 -83 kHz (H) / 56 -76 Hz (V)',
#     'LowBlue Mode': 'Yes',
#     'sRGB': 'Yes',
#     'Signal Input': 'VGA (Analog )',
#     'Sync Input': 'Separate Sync',
#     'Audio (In/Out)': 'PC audio-in',
#     'Built-in Speakers': '2W x 2',
#     'User convenience': 'Power On/Off',
#     'OSD Languages': 'Brazil Portuguese',
#     'Other convenience': 'Kensington lock',
#     'Plug & Play Compatibility': 'DDC/CI',
#     'Tilt': '-5/20\n                                                        \n                                                            \xa0degree',
#     'On mode': '13.09 W (typ.) (EnergyStar 7.0 test method)',
#     'Standby mode': '0.5 W (typ.)',
#     'Off mode': '0.5 W (typ.)',
#     'Power LED indicator': 'Operation - White',
#     'Power supply': 'Built-in',
#     'Product with stand (mm)': '490 x 368 x 195\n                                                        \n                                                            \xa0mm',
#     'Product without stand (mm)': '490 x 296 x 45\n                                                        \n                                                            \xa0mm',
#     'Packaging in mm (WxHxD)': '575 x 440 x 113\n                                                        \n                                                            \xa0mm',
#     'Product with stand (kg)': '2.92\n                                                        \n                                                            \xa0kg',
#     'Product without stand (kg)': '2.56\n                                                        \n                                                            \xa0kg',
#     'Product with packaging (kg)': '4.23\n                                                        \n                                                            \xa0kg',
#     'Temperature range (operation)': '0°C to 40°C\n                                                        \n                                                            \xa0°C',
#     'Temperature range (storage)': '-20°C to 60°C\n                                                        \n                                                            \xa0°C',
#     'Relative humidity': '20%-80\n                                                        \n                                                            \xa0%',
#     'Altitude': 'Operation: +12,000ft (3,658m), Non-operation: +40,000ft (12,192m)',
#     'MTBF': '50,000 (Excluded backlight)\n                                                        \n                                                            \xa0hour(s)',
#     'Environmental and energy': 'EnergyStar 7.0',
#     'Recyclable packaging material': '100\n                                                        \n                                                            \xa0%',
#     'Regulatory Approvals': 'WEEE',
#     'Color': 'White',
#     'Finish': 'Textured'}}},
#  'Media players': {},
#  'Home Audio': {'Multimedia Speakers 2.0': {'Product code': 'SPA9120B/94',
#    'Technical Specification': {'Output power in total': '120 W',
#     'Frequency range': '40 Hz - 20 kHz',
#     'Signal/Noise ratio': '>70 dB',
#     'THD': '<10%',
#     'Rated output power': '60 W x 2',
#     'Channel separation': '>35 dB',
#     'Input sensitivity': '600mV',
#     'Speaker driver': 'Woofer - 10 inch 4 ohm, Mid-range - 4 inch 4 ohm, Tweeter - 2 inch 8 ohm',
#     'Driver power range': '60 W x 2',
#     'Norminal impedance': '4 ohm',
#     'Sensitivity': '84 dB (2.83V/1 m)',
#     'Cable length': '1.5 m',
#     'Connector': '3.5 mm RCA',
#     'Microphone': 'Microphone socket',
#     'USB': 'USB 2.0',
#     'Quick installation guide': 'Yes',
#     'Number of satellites': '2'}},
#   'Multimedia Speakers 2.1': {'Product code': 'MMS2160B/94',
#    'Technical Specification': {'Subwoofer driver': '5.25"',
#     'Speaker driver': '3"',
#     'Bluetooth range': 'Line of sight, 10M or 30FT',
#     'USB': 'Yes',
#     'Included accessories': 'Remote control',
#     'Satellite': 'W94.6*H434.8*D84.3',
#     'Subwoofer': 'W170*H312*D335',
#     'Packaging dimensions (WxDxH)': '415 * 280 *558',
#     'Works with': 'most Bluetooth smartphones',
#     'Output power in total': '60W',
#     'Speaker output power': '2 x 15\n                                                        \n                                                            \xa0W',
#     'Subwoofer output power': '30\n                                                        \n                                                            \xa0W',
#     'Tuner bands': 'FM'}},
#   'Multimedia speaker 4.1': {'Product code': 'SPA8140B/94',
#    'Technical Specification': {'Subwoofer driver': '5 1/4"',
#     'Bass level control': 'Remote control - mode selection to control subwoofer, satellite speaker',
#     'Power on/off button': 'ON Subwoofer',
#     'Cable length': '1.3 m',
#     'Connector': 'RCA x 6',
#     'Power on indication': 'Yes',
#     'Remote control': 'Yes',
#     'Included accessories': 'Remote control',
#     'Satellite': 'W170 * H105* D90',
#     'Subwoofer': 'Yes',
#     'Packaging dimensions (WxDxH)': '311 * 381 * 392',
#     'Power LED indicator': 'Red',
#     'Mp3 player': 'Yes\n                                                        \n                                                            \xa0in',
#     'Mobile phones and mp3 players': 'Yes',
#     'PCs and laptops': 'Yes',
#     'Works with': 'music devices',
#     'other Bluetooth-enabled device': 'Yes',
#     'Frequency range': '40Hz - 150 Hz',
#     'Output power in total': '50 W',
#     'Power': '230V, 50 Hz',
#     'Signal/Noise ratio': '> 60 dB',
#     'THD': '< 10 %',
#     'Audio power amplifier': 'Class - AB amplifier',
#     'Channel separation': '>35 dB',
#     'Input sensitivity': '550 mV',
#     'Rated output power': '10 W X 4',
#     'Driver power range': '30W',
#     'Norminal impedance': '4 ohm',
#     'Sensitivity': '85 dB',
#     'Speaker driver': '3"Full range',
#     'Tuner bands': 'FM'}}},
#  'Soundbars': {'Soundbar speaker': {'Product code': 'HTL3310/10',
#    'Technical Specification': {'Speaker output power': '100W',
#     'Subwoofer output power': '60W',
#     'Speaker system output power': '160W',
#     'Main unit speaker drivers': 'L: full range (52mm/2") + tweeter; R: full range (52mm/2") + tweeter',
#     'Subwoofer type': 'Active',
#     'Subwoofer drivers': '1 x low frequency (127mm/5.0")',
#     'Integrated Connections': 'Bluetooth',
#     'Rear Connections': 'Digital optical in',
#     'EasyLink (HDMI-CEC)': 'Audio Return Channel',
#     'Wall mountable': 'Yes',
#     'Standby power consumption': 'Main unit: <0.5 W; Subwoofer: <2 W',
#     'Subwoofer power consumption': '20\n                                                        \n                                                            \xa0W',
#     'Main unit power consumption': '25\n                                                        \n                                                            \xa0W',
#     'Main unit power supply': '100-240V AC, 50/60 Hz',
#     'Subwoofer Power supply': '100-240 V~; 50-60 Hz',
#     'Main Unit (W x H x D)': '800 x 67.3 x 81.7\n                                                        \n                                                            \xa0mm',
#     'Subwoofer (W x H x D)': '120 x 400 x 300\n                                                        \n                                                            \xa0mm',
#     'Included accessories': '1 x CR2025 Battery',
#     'Number of products included': '1',
#     'Height': '58\n                                                        \n                                                            \xa0cm',
#     'Width': '17\n                                                        \n                                                            \xa0cm',
#     'Depth': '15\n                                                        \n                                                            \xa0cm',
#     'Gross weight': '15\n                                                        \n                                                            \xa0kg',
#     'Nett weight': '10\n                                                        \n                                                            \xa0kg',
#     'Tare weight': '5\n                                                        \n                                                            \xa0kg',
#     'EAN': '48 95229 10209 5',
#     'Number of consumer packagings': '2',
#     'Length': '99.5\n                                                        \n                                                            \xa0cm',
#     'GTIN': '1 48 95229 10209 2',
#     'HDMI ARC': 'Dolby Digital',
#     'Optical': 'Dolby Digital',
#     'Bluetooth': 'SBC',
#     'USB': 'MP3'}}},
#  'Headphones': {'Hi-Res Audio wireless in-ear headphones,': {'Product code': 'TAPN505BK/00',
#    'Technical Specification': {'Color': 'Black',
#     'USB cable': 'Yes',
#     'Travel case': 'Yes',
#     '3.5mm audio cable': 'Yes',
#     'Quick start guide': 'Yes',
#     'Ear caps': '3 sizes',
#     'Bluetooth profiles': 'A2DP',
#     'Bluetooth version': '5.0',
#     'Maximum range': 'Up to 10\n                                                        \n                                                            \xa0m',
#     'Volume control': 'Yes',
#     'Call Management': 'Call on Hold',
#     'Battery type': 'Li-Polymer',
#     'Rechargeable': 'Yes',
#     'Standby time': '160* hr',
#     'Talk time': '14 hr',
#     'Music play time': '14\n                                                        \n                                                            \xa0hr',
#     'Acoustic system': 'Closed',
#     'Diaphragm': 'PET',
#     'Frequency range': '7 - 40 000 Hz* 20-20,000 Hz (bluetooth)',
#     'Impedance': '16 Ohm',
#     'Magnet type': 'Neodymium',
#     'Maximum power input': '10 mW',
#     'Sensitivity': '93\n                                                        \n                                                            \xa0dB',
#     'Speaker diameter': '13 mm',
#     'GTIN': '1 48 95229 10185 9',
#     'Height': '22\n                                                        \n                                                            \xa0cm',
#     'Length': '43.2\n                                                        \n                                                            \xa0cm',
#     'Number of consumer packagings': '24',
#     'Width': '17\n                                                        \n                                                            \xa0cm',
#     'Gross weight': '0.26\n                                                        \n                                                            \xa0kg',
#     'Nett weight': '0.034\n                                                        \n                                                            \xa0kg',
#     'Tare weight': '0.226\n                                                        \n                                                            \xa0kg',
#     'Depth': '3\n                                                        \n                                                            \xa0cm',
#     'EAN': '48 95229 10185 2',
#     'Number of products included': '1'}},
#   'In-ear true wireless headphones': {'Product code': 'SHB2515BK/00',
#    'Technical Specification': {'Ear caps': '3 sizes',
#     'Included': 'USB charging cable',
#     'Quick start guide': 'Yes',
#     'Travel case': 'Yes',
#     'Microphone': 'Built-in microphone',
#     'Bluetooth profiles': 'A2DP',
#     'Bluetooth version': '5.0',
#     'Maximum range': '10\n                                                        \n                                                            \xa0m',
#     'Color': 'Black',
#     'Battery Type': 'Lithium-ion',
#     'Charging time': '2\n                                                        \n                                                            \xa0hr',
#     'Talk time': '3+70 hr',
#     'Frequency response': '20 - 20 000\n                                                        \n                                                            \xa0Hz',
#     'Impedance': '16 Ohm',
#     'Maximum power input': '5\n                                                        \n                                                            \xa0mW',
#     'Sensitivity': '90\n                                                        \n                                                            \xa0dB',
#     'Speaker diameter': '6\n                                                        \n                                                            \xa0mm',
#     'Number of consumer packagings': '24',
#     'Length': '37.5\n                                                        \n                                                            \xa0cm',
#     'Width': '9.5\n                                                        \n                                                            \xa0cm',
#     'Height': '15\n                                                        \n                                                            \xa0cm',
#     'Gross weight': '0.19\n                                                        \n                                                            \xa0kg',
#     'Tare weight': '0.074\n                                                        \n                                                            \xa0kg',
#     'GTIN': '1 69 51613 99399 3',
#     'Nett weight': '0.116\n                                                        \n                                                            \xa0kg',
#     'Depth': '5\n                                                        \n                                                            \xa0cm',
#     'Packaging type': 'Carton',
#     'Type of shelf placement': 'Both',
#     'EAN': '69 51613 99399 6',
#     'Number of products included': '1'}},
#   'Bluetooth Headset': {'Product code': 'SHB3175BK/00',
#    'Technical Specification': {'Color': 'Black',
#     'Quick start guide': 'Yes',
#     'USB cable': 'Yes',
#     'Bluetooth profiles': 'A2DP',
#     'Maximum range': 'Up to 10\n                                                        \n                                                            \xa0m',
#     'Bluetooth version': '4.1',
#     'Volume control': 'Yes',
#     'Call Management': 'Answer/End Call',
#     'Music play time': '12*\n                                                        \n                                                            \xa0hr',
#     'Standby time': '166* hrs',
#     'Talk time': '12* hrs',
#     'Battery type': 'Li-Polymer',
#     'Rechargeable': 'Yes',
#     'Frequency range': '8 - 21 500 Hz',
#     'Impedance': '32 ohm',
#     'Magnet type': 'Neodymium',
#     'Maximum power input': '40 mW',
#     'Speaker diameter': '40 mm',
#     'Sensitivity': '104 dB',
#     'Acoustic system': 'Closed',
#     'EAN': '69 51613 99168 8',
#     'Depth': '1.8\n                                                        \n                                                            \xa0inch',
#     'Gross weight': '1.216\n                                                        \n                                                            \xa0kg',
#     'Height': '18.5\n                                                        \n                                                            \xa0cm',
#     'Nett weight': '0.672\n                                                        \n                                                            \xa0kg',
#     'Number of products included': '1',
#     'Tare weight': '0.544\n                                                        \n                                                            \xa0kg',
#     'Width': '7.5\n                                                        \n                                                            \xa0inch',
#     'Packaging type': 'Carton',
#     'Type of shelf placement': 'Both',
#     'GTIN': '1 69 51613 99168 5',
#     'Length': '8.3\n                                                        \n                                                            \xa0inch',
#     'Number of consumer packagings': '3',
#     'Weight': '0.19\n                                                        \n                                                            \xa0kg'}}},
#  'Wireless Speakers': {'S6305 BT speaker, power bank function': {'Product code': 'TAS6305/00',
#    'Technical Specification': {'Android tablets & smartphones': 'with Android 2.1 and Bluetooth 2.1 or above',
#     'Output power (RMS)': '2 x 10W',
#     'Rated power': '30W',
#     'Sound System': 'Stereo',
#     'Speaker drivers': '2 x 2.25" full range driver and 2 passive radiator',
#     'Bluetooth profiles': 'A2DP',
#     'Bluetooth range': 'Line of sight, 20m or 66ft',
#     'Bluetooth version': '5.0',
#     'USB charging': '5V, 2A',
#     'Audio Connections': '3.5mm Line in',
#     'Wireless': 'Yes, TWS pairing',
#     'Water resistance': 'IPX7',
#     'Ease of Installation': 'Automatic pairing',
#     'Volume control': 'Digital up/down',
#     'Automatic power off': 'Yes',
#     'Call Management': 'Answer/End Call',
#     'Power LED indicator': 'Blue',
#     'Battery type': 'Lithium-ion (built-in)',
#     'Battery Capacity': '4400mAh, 7.4V',
#     'Operating time on battery': '20\n                                                        \n                                                            \xa0hr',
#     'Charging time': '6\n                                                        \n                                                            \xa0hr',
#     '3.5mm audio cable': 'Yes',
#     'Cable': 'USB charging cable',
#     'Included accessories': 'Quick install guide',
#     'Product dimensions (WxDxH)': '230 x 100 x 100\n                                                        \n                                                            \xa0mm',
#     'Packaging dimensions (WxDxH)': '288 x 130 x 130 mm',
#     'Product weight': '0.8\n                                                        \n                                                            \xa0kg',
#     'Weight incl. Packaging': '1.0\n                                                        \n                                                            \xa0kg',
#     'Color': 'Black'}},
#   'wireless portable speaker': {'Product code': 'BT50A/00',
#    'Technical Specification': {'iPad': 'iPad 1',
#     'iPhone': 'iPhone 3',
#     'iPod touch': '3rd generation or later',
#     'Android tablets & smartphones': 'with Android 2.1 and Bluetooth 2.1 or above',
#     'work with': 'Bluetooth 4.0 or below',
#     'other Bluetooth-enabled device': 'Yes',
#     'Color': 'Aqua',
#     'Bluetooth profiles': 'A2DP',
#     'Bluetooth range': 'Line of sight, 10M or 30FT',
#     'Audio in (3.5mm)': 'Yes',
#     'USB charging': 'Yes',
#     'Output power (RMS)': '2W',
#     'Sound System': 'Mono',
#     'Speaker driver': '1 x 1.5"',
#     'Operating time on battery': '6\n                                                        \n                                                            \xa0hr',
#     'Battery type': 'lithium polymer (built-in)',
#     'Included accessories': 'USB cable for PC charging',
#     'Product dimensions (WxDxH)': '6.1 x 6.1 x 7.6 cm',
#     'Packaging dimensions (WxDxH)': '8.1 x 9.5 x 14 cm',
#     'Product weight': '0.09\n                                                        \n                                                            \xa0kg',
#     'Weight incl. Packaging': '0.2\n                                                        \n                                                            \xa0kg'}}},
#  'Mobile & tablets': {},
#  'Data storage': {},
#  'Audio & video': {},
#  'Batteries & chargers': {},
#  'Power solutions': {},
#  'Mobile accessories': {},
#  'Computer accessories': {},
#  'OneBlade – Shape, trim and shave': {'Face': {'Product code': 'QP2512/10',
#    'Technical Specification': {'Shaving system': 'Contour-following technology',
#     'Trimming system': 'Contour-following technology',
#     'Comb': '3 stubble combs (1, 3, 5 mm)',
#     'Charging': '8 hours full charge',
#     'Wet and dry use': 'Yes',
#     'Color': 'Lime green, charcoal grey',
#     'Handle': 'Ribbed rubber grip',
#     'Run time': '30 minutes',
#     'Battery type': 'Ni-MH',
#     'Automatic voltage': '100-240 V',
#     'Max power consumption': '2\n                                                        \n                                                            \xa0W',
#     '2-year guarantee': '2-year guarantee on the handle',
#     'Replacement head': 'QP210, QP220, QP610, QP620'}},
#   'Replaceable blade': {'Product code': 'QP220/50',
#    'Technical Specification': {}}},
#  'FACE Shavers': {},
#  'Beard Trimmers and Grooming Kits': {},
#  'HAIR clippers': {},
#  'BODY groomers': {'': {'Product code': ''}},
#  'Beauty Tips for Women': {},
#  'Satinelle epilator': {},
#  'Hair removal': {},
#  'Haircare': {},
#  'Oral Healthcare Homepage': {},
#  'Electric Toothbrushes': {'Sonic electric toothbrush': {'Product code': 'HX6311/07',
#    'Technical Specification': {'Power modes': '2',
#     'Handles': '1 Sonicare for Kids',
#     'Brush heads': '1 Sonicare for Kids standard',
#     'Charger': '1',
#     'Stickers': '8 customization stickers',
#     'Color': 'Aqua',
#     'Speed': 'Up to 62000 brush movement/min',
#     'Performance': '75% more effective*',
#     'Health benefits': 'For healthy oral care habits',
#     'Timer': 'KidTimer and Quadpacer',
#     'Brush head system': 'Easy click-on brush heads',
#     'Brushing time': 'Up to 3 weeks**',
#     'Battery indicator': 'Light shows battery status',
#     'Handle': 'Slim ergonomic design',
#     'Display': 'Illuminated display',
#     'Battery': 'Rechargeable',
#     'Battery type': 'Lithium ION',
#     'Operating time (full to empty)': 'Up to 3 weeks**',
#     'Voltage': '100-240 V',
#     'Warranty': '2-year limited warranty'}}},
#  'Toothbrush heads': {},
#  'Philips Sonicare AirFloss': {},
#  'Teeth Whitening': {},
#  'Philips Avent homepage': {},
#  'Healthcare professionals': {},
#  'Breast pumps & care': {},
#  'Baby bottles & nipples': {},
#  'Bottle warmers & sterilizers': {},
#  'Food makers & tableware': {},
#  'Pacifiers': {},
#  'Toddler sippy cups': {},
#  'Coffee': {},
#  'Kettles': {'Kettle': {'Product code': 'HD9303/02',
#    'Technical Specification': {'Color(s)': 'Metallic silver',
#     'Heating element': 'Stainless steel',
#     'Material housing': 'Stainless steel',
#     'Capacity': '1.2 L',
#     'Cord length': '0.75 m',
#     'Frequency': '50\n                                                        \n                                                            \xa0Hz',
#     'Power': '1800\n                                                        \n                                                            \xa0W',
#     'Voltage': '230 V',
#     'Product dimensions (WxDxH)': '22x16x19\n                                                        \n                                                            \xa0cm',
#     'Packaging dimensions (WxDxH)': '18x18x20.9\n                                                        \n                                                            \xa0cm',
#     'Product weight': '0.8\n                                                        \n                                                            \xa0kg'}},
#   'Double Wall': {'Product code': 'HD9329/06',
#    'Technical Specification': {'Made in': 'China',
#     'Product features': '360 degrees base',
#     '2-year worldwide guarantee': 'Yes',
#     'Packaging': '> 90% recycled materials',
#     'User manual': '100% recycled paper',
#     'Cord length': '0.75\n                                                        \n                                                            \xa0m',
#     'Frequency': '50/60\n                                                        \n                                                            \xa0Hz',
#     'Power': '1920\n                                                        \n                                                            \xa0W',
#     'Voltage': '220\n                                                        \n                                                            \xa0V',
#     'Dimensions of packaging (LxWxH)': '235x220x255\n                                                        \n                                                            \xa0mm',
#     'Weight incl. packaging': '1.55\n                                                        \n                                                            \xa0kg',
#     'Weight of product': '1.124\n                                                        \n                                                            \xa0kg',
#     'Color': 'Pistil red & Deep black',
#     'Material filter': 'Stainless steel',
#     'Material heating element': 'Stainless steel'}}},
#  'Cooking': {},
#  'Food Preparation': {},
#  'Vacuum Cleaners': {},
#  'Ironing': {},
#  'Garment steamers': {'Handheld garment steamer': {'Product code': 'GC360/30',
#    'Technical Specification': {'Continuous steam': 'Up to 22\n                                                        \n                                                            \xa0g/min',
#     'Power': '1200\n                                                        \n                                                            \xa0W',
#     'Ready to use': 'Light indicator',
#     'Voltage': '220-240\n                                                        \n                                                            \xa0V',
#     'Safe on all ironable fabrics': 'Even delicates like silk',
#     'Water tank capacity': '70\n                                                        \n                                                            \xa0ml',
#     'Detachable water tank': 'Yes',
#     'Power cord length': '2.5\n                                                        \n                                                            \xa0m',
#     'Refill any time during use': 'Yes',
#     'Brush': 'Yes',
#     'Glove for extra protection': 'Yes',
#     'Packaging dimensions (WxHxL)': '38 x 12.8 x 15\n                                                        \n                                                            \xa0cm',
#     '2 year worldwide guarantee': 'Yes',
#     'Product packaging': '100% recycable',
#     'User manual': '100% recycled paper'}},
#   'Garment Steamer': {'Product code': 'GC523',
#    'Technical Specification': {'Continuous steam': '32\n                                                        \n                                                            \xa0g/min',
#     'Power': '1600\n                                                        \n                                                            \xa0W',
#     'Ready to use': '<1\n                                                        \n                                                            \xa0min',
#     'Variable steam': '5\n                                                        \n                                                            \xa0levels',
#     'Variable steam levels': 'Yes',
#     'Vertical steam': 'Yes',
#     'Voltage': '220-240\n                                                        \n                                                            \xa0V',
#     'Safe on all ironable fabrics': 'Even delicates like silk',
#     'Water tank capacity': '1600\n                                                        \n                                                            \xa0ml',
#     'Detachable water tank': 'Yes',
#     'Integrated power plug': 'Yes',
#     'Descaling and cleaning': 'Easy De-calc',
#     'Brush': 'Yes',
#     'Glove for extra protection': 'Yes',
#     'Pleat maker': 'Yes',
#     'Adjustable double pole': 'Yes',
#     'Support accessory': 'Yes',
#     'Garment hanger w trouser clips': 'Yes',
#     '2 year worldwide guarantee': 'Yes',
#     'Product packaging': '100% recycable',
#     'User manual': '100% recycled paper'}}},
#  'Air purifier and Air humidifier': {},
#  'Philips Hue': {},
#  'Consumer lighting': {},
#  'Hearing solutions': {},
#  'COPD Solutions': {},
#  'Sleep apnea Therapy': {},
#  'Car lights': {},
#  'Halogen': {},
#  'LED': {},
#  'All car lights': {'Headlight bulb': {'Product code': '9005WHVB1',
#    'Technical Specification': {'Technology': 'Halogen',
#     'Type': 'HB3',
#     'Range': 'WhiteVision',
#     'Application': 'High beam',
#     'Homologation ECE': 'YES',
#     'Base': 'P20d',
#     'Designation': 'HB3 9005 WHV 12.8V 65W P20d',
#     'Voltage': '12\n                                                        \n                                                            \xa0V',
#     'Wattage': '60W\n                                                        \n                                                            \xa0W',
#     'Color temperature': 'up to 4300 K',
#     'Lumens': '1860+/-12%',
#     'Life time': '400h',
#     'Order entry': '9005WHVB1',
#     'Ordering code': '37475930',
#     'EAN1': '8727900374759',
#     'EAN3': '8727900374766',
#     'Packaging type': 'B1',
#     'Pack Quantity': '1',
#     'MOQ (for professionals)': '10',
#     'Gross weight per piece': '0.42\n                                                        \n                                                            \xa0kg',
#     'Height': '13\n                                                        \n                                                            \xa0cm',
#     'Length': '19\n                                                        \n                                                            \xa0cm',
#     'Width': '19\n                                                        \n                                                            \xa0cm',
#     'Net weight': '42\n                                                        \n                                                            \xa0g',
#     'Net weight per piece': '0.197\n                                                        \n                                                            \xa0g',
#     'Expected benefits': 'Style',
#     'Product highlight': 'Intense white xenon effect'}},
#   'car headlight bulb': {'Product code': '9006XVGB1',
#    'Technical Specification': {'Packaging type': 'Blister',
#     'EAN1': '8719018001948',
#     'EAN3': '8719018001955',
#     'Voltage': '12\n                                                        \n                                                            \xa0V',
#     'Wattage': '51 W',
#     'Life time': '600\xa0hrs',
#     'Lumens': '1095 ±15%',
#     'Color temperature': '3350\n                                                        \n                                                            \xa0K',
#     'Order entry': '9006XVGB1',
#     'Ordering code': '194830',
#     'Height': '13.3\n                                                        \n                                                            \xa0cm',
#     'Length': '9.5\n                                                        \n                                                            \xa0cm',
#     'Width': '5.3\n                                                        \n                                                            \xa0cm',
#     'Gross weight per piece': '0.35\n                                                        \n                                                            \xa0kg',
#     'Type': 'HB4',
#     'Application': 'High beam',
#     'Homologation ECE': 'YES',
#     'Range': 'X-tremeVision G-force',
#     'Technology': 'Halogen',
#     'Designation': '9006XVGB1',
#     'Base': 'P22d',
#     'MOQ (for professionals)': '10',
#     'Pack Quantity': '1',
#     'Gross weight per piece [g]': '22.7',
#     'Expected benefits': 'More light',
#     'Product highlight': 'More light'}}},
#  'Motorcycle lights': {},
#  'All motorcycle lights': {'Headlight bulb': {'Product code': '12153BVB1',
#    'Technical Specification': {'Packaging type': 'B1',
#     'EAN1': '8727900534337',
#     'EAN3': '8727900534344',
#     'Color temperature': 'up to 3700\n                                                        \n                                                            \xa0K',
#     'Lumens': '550.0 ± 15%\n                                                        \n                                                            \xa0lm',
#     'Expected benefits': 'White light',
#     'Product highlight': '3700K',
#     'Designation': 'M5 BlueVision',
#     'Range': 'BlueVision Moto',
#     'Technology': 'Halogen',
#     'Base': 'P15d-25-1',
#     'Application': 'High beam',
#     'Type': 'M5',
#     'Marking ECE': 'N/A',
#     'Homologation ECE': 'NO',
#     'Life time': '150h',
#     'Voltage': '12\n                                                        \n                                                            \xa0V',
#     'Wattage': '35/35\n                                                        \n                                                            \xa0W',
#     'Ordering code': '53433730',
#     'Order entry': '12153BVB1',
#     'Gross weight per piece': '0.393\n                                                        \n                                                            \xa0g',
#     'Height': '14.6\n                                                        \n                                                            \xa0cm',
#     'Length': '20.1\n                                                        \n                                                            \xa0cm',
#     'Net weight per piece': '93\n                                                        \n                                                            \xa0g',
#     'Pack Quantity / MOQ': '10',
#     'Width': '14.4\n                                                        \n                                                            \xa0cm'}},
#   'Motorcycle headlight bulb': {'Product code': '11342UMX1',
#    'Technical Specification': {'Packaging type': 'X1',
#     'EAN1': '8719018051905',
#     'EAN3': '8719018051912',
#     'Color temperature': '6000\n                                                        \n                                                            \xa0K',
#     'Expected benefits': 'LED moto performance',
#     'Product highlight': 'LED moto performance',
#     'Range': 'Ultinon moto',
#     'Technology': 'LED',
#     'Base': 'P43t-38',
#     'Application': 'High beam',
#     'Type': 'LED-HL [~H4]',
#     'Homologation ECE': 'NO',
#     'Designation': 'LED-HL [˜H4]',
#     'Life time': '5 years',
#     'Voltage': '12\n                                                        \n                                                            \xa0V',
#     'Wattage': '17\n                                                        \n                                                            \xa0W',
#     'Ordering code': '6002031',
#     'Order entry': '11342UMX1',
#     'Pack Quantity': '1'}}},
#  'Car accessories': {'interior and signaling bulb': {'Product code': '12956X2',
#    'Technical Specification': {'Application': 'Front position',
#     'Technology': 'LED',
#     'Type': '[~5W]',
#     'Range': 'LED CANbus',
#     'Designation': 'CEA 12956 12V 5W X2',
#     'Homologation ECE': 'NO',
#     'Expected benefits': 'More light',
#     'Product highlight': 'LED warning canceller',
#     'Voltage': '12\n                                                        \n                                                            \xa0V',
#     'Wattage': '5\n                                                        \n                                                            \xa0W'}}},
#  'Car air quality': {},
#  'Automotive support': {},
#  'Automotive articles': {},
#  'Where to buy': {},
#  'Parts and accessories': {}}
